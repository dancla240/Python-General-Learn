# %% [markdown]
# ## Testning

# %% [markdown]
# ### Pytest
# - [Pytest Dokumentation](https://docs.pytest.org/en/stable/)

# %%
# Arrange
a = 1
b = 2
expected = 3

# Act
result = sum([a, b])

# Assert
assert result == expected
